# %% [markdown]
# <a href="https://colab.research.google.com/github/ccardensa/AutoMapper/blob/master/Lab_3_Generalizaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Apredizaje y generalización
#
# Keras también nos ayuda a entrenar redes que sean capaces de generalizar de manera muy  simple. En este laboratorio usaremos un conjunto de entrenamiento (train) y otro conjunto diferente de prueba o validación (test). La idea es que entrenaremos con uno y evaluaremos el desempeño de nuestra red en el otro.
#
# También veremos cómo la regularización ayuda a mejorar la generalización.

# %%
# Importamos librerías necesarias

import keras
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# Cargamos datos de entrenamiento y prueba de CIFAR10

(imgs_train,labs_train), (imgs_test,labs_test) = keras.datasets.cifar10.load_data()
print(imgs_train.shape)
print(imgs_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 154755072/170498071 [==========================>...] - ETA: 1s

# %%
nombres = ['avión', 'auto', 'pájaro', 'gato', 'venado', 'perro', 'rana', 'caballo', 'barco', 'camión']

# %%
# Mostramos una grilla de ejemplos (al azar) del conjunto de test

h = 6 # alto de la grilla
w = 6 # ancho de la grilla
fig, axs = plt.subplots(h, w, figsize=(1.6*h,1.6*w))
for i in range(h):
  for j in range(w):
    ex = np.random.randint(len(imgs_test))
    axs[i,j].set_title(nombres[labs_test[ex][0]])
    axs[i,j].grid(False)
    axs[i,j].set_xticklabels([])
    axs[i,j].set_yticklabels([])
    axs[i,j].imshow(imgs_test[ex])

# %%
# Tranformamos los datos para el entrenamiento,
# Necesitamos transformar tanto el train como el test

X_train = imgs_train.reshape(50000,32*32*3)
X_test = imgs_test.reshape(10000,32*32*3)
X_train = X_train / 255
X_test = X_test / 255
print('X', X_train.shape, X_test.shape)

Y_train = keras.utils.to_categorical(labs_train, 10)
Y_test = keras.utils.to_categorical(labs_test, 10)
print('Y', Y_train.shape, Y_test.shape)
# Out:
# X (50000, 3072) (10000, 3072)
# Y (50000, 10) (10000, 10)

# %%
# cantidad de ejemplos (train/test), neuronas de entrada y neuronas de salida

M_train = X_train.shape[0]
M_test = X_test.shape[0]

N = X_train.shape[1]
C = Y_train.shape[1]

print(N,C,M_train,M_test)
# Out:
# 3072 10 50000 10000

# %%
# Setamos los seed para números random

np.random.seed(30)
tf.set_random_seed(30)


# Creamos nuestra red feed-forward (tiene 4 capas escondidas!)

h1 = 512
h2 = 256

red = keras.Sequential()
red.add(keras.layers.Dense(h1, input_dim=N, activation='relu'))
red.add(keras.layers.Dense(h2, activation='relu'))
red.add(keras.layers.Dense(h2, activation='relu'))
red.add(keras.layers.Dense(C, activation='softmax'))

red.summary()

red.compile(
    loss='categorical_crossentropy',
    optimizer='sgd',
    metrics=['accuracy']
)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,773,066
# Trainable params: 1,773,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = red.fit(X_train, Y_train,
        epochs=150,
        batch_size=128,
        validation_data=(X_test,Y_test)
       )
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/150
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.9835 - acc: 0.2931 - val_loss: 1.8626 - val_acc: 0.3428
# Epoch 2/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.8058 - acc: 0.3605 - val_loss: 1.8002 - val_acc: 0.3469
# Epoch 3/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.7355 - acc: 0.3884 - val_loss: 1.7368 - val_acc: 0.3854
# Epoch 4/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.6852 - acc: 0.4059 - val_loss: 1.6585 - val_acc: 0.4195
# Epoch 5/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.6417 - acc: 0.4218 - val_loss: 1.6398 - val_acc: 0.4253
# Epoch 6/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.6108 - acc: 0.4349 - val_loss: 1.6063 - val_acc: 0.4264
# Epoch 7/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.5816 - acc: 0.4430 - val_loss: 1.5561 - val_acc: 0.4528
# Epoch 8/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.5557 - acc: 0.4519 - val_loss: 1.5742 - val_acc: 0.4394
# Epoch 9/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.5327 - acc: 0.4595 - val_loss: 1.5401 - val_acc: 0.4580
# Epoch 10/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.5114 - acc: 0.4664 - val_loss: 1.5396 - val_acc: 0.4494
# Epoch 11/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.4901 - acc: 0.4750 - val_loss: 1.5020 - val_acc: 0.4632
# Epoch 12/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.4704 - acc: 0.4821 - val_loss: 1.5064 - val_acc: 0.4615
# Epoch 13/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.4551 - acc: 0.4880 - val_loss: 1.4947 - val_acc: 0.4646
# Epoch 14/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.4375 - acc: 0.4936 - val_loss: 1.4732 - val_acc: 0.4768
# Epoch 15/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.4205 - acc: 0.4985 - val_loss: 1.4535 - val_acc: 0.4809
# Epoch 16/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.4039 - acc: 0.5054 - val_loss: 1.4442 - val_acc: 0.4870
# Epoch 17/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.3881 - acc: 0.5123 - val_loss: 1.4898 - val_acc: 0.4712
# Epoch 18/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.3731 - acc: 0.5153 - val_loss: 1.4227 - val_acc: 0.4953
# Epoch 19/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.3642 - acc: 0.5196 - val_loss: 1.3971 - val_acc: 0.5022
# Epoch 20/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.3487 - acc: 0.5230 - val_loss: 1.4687 - val_acc: 0.4774
# Epoch 21/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.3372 - acc: 0.5277 - val_loss: 1.4312 - val_acc: 0.4870
# Epoch 22/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.3224 - acc: 0.5337 - val_loss: 1.4265 - val_acc: 0.4895
# Epoch 23/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.3097 - acc: 0.5380 - val_loss: 1.4099 - val_acc: 0.4923
# Epoch 24/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2959 - acc: 0.5439 - val_loss: 1.3650 - val_acc: 0.5134
# Epoch 25/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2874 - acc: 0.5463 - val_loss: 1.4130 - val_acc: 0.4999
# Epoch 26/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2716 - acc: 0.5531 - val_loss: 1.3789 - val_acc: 0.5097
# Epoch 27/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2659 - acc: 0.5554 - val_loss: 1.3631 - val_acc: 0.5124
# Epoch 28/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2508 - acc: 0.5606 - val_loss: 1.4447 - val_acc: 0.4927
# Epoch 29/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2402 - acc: 0.5629 - val_loss: 1.3595 - val_acc: 0.5127
# Epoch 30/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2287 - acc: 0.5683 - val_loss: 1.3550 - val_acc: 0.5207
# Epoch 31/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2226 - acc: 0.5708 - val_loss: 1.3503 - val_acc: 0.5211
# Epoch 32/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2052 - acc: 0.5770 - val_loss: 1.4011 - val_acc: 0.5089
# Epoch 33/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2008 - acc: 0.5799 - val_loss: 1.4394 - val_acc: 0.4931
# Epoch 34/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.1895 - acc: 0.5823 - val_loss: 1.3852 - val_acc: 0.5087
# Epoch 35/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.1801 - acc: 0.5855 - val_loss: 1.3546 - val_acc: 0.5177
# Epoch 36/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.1697 - acc: 0.5882 - val_loss: 1.3844 - val_acc: 0.5067
# Epoch 37/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.1624 - acc: 0.5924 - val_loss: 1.3536 - val_acc: 0.5263
# Epoch 38/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.1510 - acc: 0.5966 - val_loss: 1.3269 - val_acc: 0.5274
# Epoch 39/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.1383 - acc: 0.5999 - val_loss: 1.3401 - val_acc: 0.5216
# Epoch 40/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.1324 - acc: 0.6028 - val_loss: 1.3304 - val_acc: 0.5322
# Epoch 41/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.1201 - acc: 0.6060 - val_loss: 1.3328 - val_acc: 0.5358
# Epoch 42/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.1172 - acc: 0.6100 - val_loss: 1.3203 - val_acc: 0.5295
# Epoch 43/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.1026 - acc: 0.6120 - val_loss: 1.3424 - val_acc: 0.5225
# Epoch 44/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0896 - acc: 0.6161 - val_loss: 1.3423 - val_acc: 0.5248
# Epoch 45/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0829 - acc: 0.6197 - val_loss: 1.4156 - val_acc: 0.5116
# Epoch 46/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0739 - acc: 0.6225 - val_loss: 1.3164 - val_acc: 0.5320
# Epoch 47/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0645 - acc: 0.6259 - val_loss: 1.3502 - val_acc: 0.5306
# Epoch 48/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0590 - acc: 0.6282 - val_loss: 1.3102 - val_acc: 0.5317
# Epoch 49/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0463 - acc: 0.6338 - val_loss: 1.4122 - val_acc: 0.5015
# Epoch 50/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0357 - acc: 0.6358 - val_loss: 1.4196 - val_acc: 0.5070
# Epoch 51/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0327 - acc: 0.6359 - val_loss: 1.4383 - val_acc: 0.5061
# Epoch 52/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.0227 - acc: 0.6419 - val_loss: 1.3407 - val_acc: 0.5330
# Epoch 53/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0119 - acc: 0.6452 - val_loss: 1.3202 - val_acc: 0.5408
# Epoch 54/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0011 - acc: 0.6474 - val_loss: 1.3201 - val_acc: 0.5327
# Epoch 55/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9882 - acc: 0.6546 - val_loss: 1.3035 - val_acc: 0.5494
# Epoch 56/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9845 - acc: 0.6543 - val_loss: 1.3230 - val_acc: 0.5400
# Epoch 57/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9812 - acc: 0.6562 - val_loss: 1.3307 - val_acc: 0.5357
# Epoch 58/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9678 - acc: 0.6611 - val_loss: 1.3344 - val_acc: 0.5393
# Epoch 59/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.9583 - acc: 0.6642 - val_loss: 1.3415 - val_acc: 0.5330
# Epoch 60/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.9497 - acc: 0.6671 - val_loss: 1.3337 - val_acc: 0.5382
# Epoch 61/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.9462 - acc: 0.6698 - val_loss: 1.3829 - val_acc: 0.5234
# Epoch 62/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9266 - acc: 0.6726 - val_loss: 1.3358 - val_acc: 0.5450
# Epoch 63/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9256 - acc: 0.6755 - val_loss: 1.3284 - val_acc: 0.5454
# Epoch 64/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9148 - acc: 0.6802 - val_loss: 1.4245 - val_acc: 0.5161
# Epoch 65/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9047 - acc: 0.6835 - val_loss: 1.3390 - val_acc: 0.5395
# Epoch 66/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8999 - acc: 0.6831 - val_loss: 1.4320 - val_acc: 0.5192
# Epoch 67/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8892 - acc: 0.6870 - val_loss: 1.5275 - val_acc: 0.4945
# Epoch 68/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8842 - acc: 0.6922 - val_loss: 1.3450 - val_acc: 0.5431
# Epoch 69/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.8684 - acc: 0.6965 - val_loss: 1.3555 - val_acc: 0.5435
# Epoch 70/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8654 - acc: 0.6974 - val_loss: 1.3188 - val_acc: 0.5484
# Epoch 71/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8503 - acc: 0.7034 - val_loss: 1.5329 - val_acc: 0.5085
# Epoch 72/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8484 - acc: 0.7039 - val_loss: 1.4635 - val_acc: 0.5220
# Epoch 73/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8466 - acc: 0.7031 - val_loss: 1.4049 - val_acc: 0.5260
# Epoch 74/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8194 - acc: 0.7128 - val_loss: 1.4446 - val_acc: 0.5221
# Epoch 75/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.8181 - acc: 0.7139 - val_loss: 1.3795 - val_acc: 0.5399
# Epoch 76/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.8135 - acc: 0.7165 - val_loss: 1.3977 - val_acc: 0.5315
# Epoch 77/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8057 - acc: 0.7184 - val_loss: 1.3291 - val_acc: 0.5539
# Epoch 78/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7900 - acc: 0.7236 - val_loss: 1.4379 - val_acc: 0.5237
# Epoch 79/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7845 - acc: 0.7258 - val_loss: 1.3807 - val_acc: 0.5477
# Epoch 80/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7728 - acc: 0.7310 - val_loss: 1.4694 - val_acc: 0.5232
# Epoch 81/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7683 - acc: 0.7306 - val_loss: 1.4508 - val_acc: 0.5243
# Epoch 82/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.7609 - acc: 0.7353 - val_loss: 1.6094 - val_acc: 0.5067
# Epoch 83/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.7561 - acc: 0.7350 - val_loss: 1.4863 - val_acc: 0.5154
# Epoch 84/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7509 - acc: 0.7373 - val_loss: 1.4822 - val_acc: 0.5263
# Epoch 85/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7424 - acc: 0.7414 - val_loss: 1.3857 - val_acc: 0.5492
# Epoch 86/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7250 - acc: 0.7481 - val_loss: 1.4029 - val_acc: 0.5423
# Epoch 87/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7204 - acc: 0.7513 - val_loss: 1.5396 - val_acc: 0.5176
# Epoch 88/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7145 - acc: 0.7519 - val_loss: 1.5328 - val_acc: 0.5083
# Epoch 89/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6976 - acc: 0.7578 - val_loss: 1.4452 - val_acc: 0.5313
# Epoch 90/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6991 - acc: 0.7577 - val_loss: 1.5682 - val_acc: 0.5099
# Epoch 91/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.6781 - acc: 0.7647 - val_loss: 1.6906 - val_acc: 0.4857
# Epoch 92/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6784 - acc: 0.7646 - val_loss: 1.5734 - val_acc: 0.5127
# Epoch 93/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6689 - acc: 0.7700 - val_loss: 1.5783 - val_acc: 0.5004
# Epoch 94/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6582 - acc: 0.7712 - val_loss: 1.5433 - val_acc: 0.5310
# Epoch 95/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6595 - acc: 0.7696 - val_loss: 1.6704 - val_acc: 0.5072
# Epoch 96/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6451 - acc: 0.7774 - val_loss: 1.5311 - val_acc: 0.5322
# Epoch 97/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6397 - acc: 0.7783 - val_loss: 1.4624 - val_acc: 0.5448
# Epoch 98/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6210 - acc: 0.7852 - val_loss: 1.5315 - val_acc: 0.5294
# Epoch 99/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.6186 - acc: 0.7847 - val_loss: 1.4902 - val_acc: 0.5338
# Epoch 100/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6073 - acc: 0.7905 - val_loss: 1.5527 - val_acc: 0.5220
# Epoch 101/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6036 - acc: 0.7915 - val_loss: 1.9183 - val_acc: 0.4855
# Epoch 102/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5950 - acc: 0.7942 - val_loss: 1.5593 - val_acc: 0.5354
# Epoch 103/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5867 - acc: 0.7955 - val_loss: 1.9635 - val_acc: 0.4742
# Epoch 104/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5780 - acc: 0.8027 - val_loss: 1.5417 - val_acc: 0.5379
# Epoch 105/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5638 - acc: 0.8065 - val_loss: 1.5642 - val_acc: 0.5315
# Epoch 106/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5561 - acc: 0.8089 - val_loss: 1.5673 - val_acc: 0.5383
# Epoch 107/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.5557 - acc: 0.8104 - val_loss: 1.6296 - val_acc: 0.5295
# Epoch 108/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.5507 - acc: 0.8108 - val_loss: 1.9216 - val_acc: 0.4878
# Epoch 109/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.5427 - acc: 0.8139 - val_loss: 1.8796 - val_acc: 0.4960
# Epoch 110/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.5321 - acc: 0.8183 - val_loss: 1.5524 - val_acc: 0.5420
# Epoch 111/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5265 - acc: 0.8202 - val_loss: 1.6933 - val_acc: 0.5197
# Epoch 112/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5269 - acc: 0.8198 - val_loss: 1.5844 - val_acc: 0.5392
# Epoch 113/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5129 - acc: 0.8257 - val_loss: 1.6911 - val_acc: 0.5203
# Epoch 114/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4958 - acc: 0.8296 - val_loss: 1.7136 - val_acc: 0.5165
# Epoch 115/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4959 - acc: 0.8306 - val_loss: 1.7530 - val_acc: 0.5136
# Epoch 116/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4869 - acc: 0.8344 - val_loss: 1.9309 - val_acc: 0.4974
# Epoch 117/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4861 - acc: 0.8330 - val_loss: 1.9075 - val_acc: 0.4990
# Epoch 118/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4722 - acc: 0.8404 - val_loss: 1.6856 - val_acc: 0.5293
# Epoch 119/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.4548 - acc: 0.8468 - val_loss: 1.6832 - val_acc: 0.5334
# Epoch 120/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4705 - acc: 0.8384 - val_loss: 1.8391 - val_acc: 0.5137
# Epoch 121/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4446 - acc: 0.8492 - val_loss: 1.6783 - val_acc: 0.5392
# Epoch 122/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4591 - acc: 0.8455 - val_loss: 1.6515 - val_acc: 0.5499
# Epoch 123/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4375 - acc: 0.8542 - val_loss: 1.6660 - val_acc: 0.5432
# Epoch 124/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4324 - acc: 0.8554 - val_loss: 1.8993 - val_acc: 0.5151
# Epoch 125/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4176 - acc: 0.8624 - val_loss: 2.2184 - val_acc: 0.4851
# Epoch 126/150
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4212 - acc: 0.8583 - val_loss: 1.7133 - val_acc: 0.5458
# Epoch 127/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4024 - acc: 0.8672 - val_loss: 1.9518 - val_acc: 0.5119
# Epoch 128/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.3955 - acc: 0.8684 - val_loss: 1.7707 - val_acc: 0.5332
# Epoch 129/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4105 - acc: 0.8656 - val_loss: 1.7818 - val_acc: 0.5379
# Epoch 130/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.3835 - acc: 0.8726 - val_loss: 1.8182 - val_acc: 0.5333
# Epoch 131/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.3943 - acc: 0.8673 - val_loss: 1.7802 - val_acc: 0.5341
# Epoch 132/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.3904 - acc: 0.8713 - val_loss: 1.7863 - val_acc: 0.5364
# Epoch 133/150
# 50000/50000 [==============================] - 4s 71us/step - loss: 0.3588 - acc: 0.8820 - val_loss: 1.8336 - val_acc: 0.5399
# Epoch 134/150
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.3556 - acc: 0.8816 - val_loss: 1.7727 - val_acc: 0.5426
# Epoch 135/150
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.3821 - acc: 0.8782 - val_loss: 1.9010 - val_acc: 0.5234
# Epoch 136/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.3431 - acc: 0.8881 - val_loss: 1.7619 - val_acc: 0.5535
# Epoch 137/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.3499 - acc: 0.8843 - val_loss: 1.9913 - val_acc: 0.5166
# Epoch 138/150
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.3465 - acc: 0.8845 - val_loss: 2.0447 - val_acc: 0.5130
# Epoch 139/150
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.3350 - acc: 0.8900 - val_loss: 1.8233 - val_acc: 0.5378
# Epoch 140/150
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.3152 - acc: 0.8962 - val_loss: 1.8635 - val_acc: 0.5315
# Epoch 141/150
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.3148 - acc: 0.8999 - val_loss: 1.9327 - val_acc: 0.5325
# Epoch 142/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.3306 - acc: 0.8946 - val_loss: 1.9679 - val_acc: 0.5285
# Epoch 143/150
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.3091 - acc: 0.9001 - val_loss: 1.8258 - val_acc: 0.5523
# Epoch 144/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.2950 - acc: 0.9046 - val_loss: 1.9106 - val_acc: 0.5453
# Epoch 145/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.3079 - acc: 0.9038 - val_loss: 1.8468 - val_acc: 0.5394
# Epoch 146/150
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.2906 - acc: 0.9081 - val_loss: 1.9514 - val_acc: 0.5396
# Epoch 147/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.2953 - acc: 0.9065 - val_loss: 1.9276 - val_acc: 0.5496
# Epoch 148/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.2751 - acc: 0.9145 - val_loss: 1.9827 - val_acc: 0.5371
# Epoch 149/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.2632 - acc: 0.9161 - val_loss: 1.9661 - val_acc: 0.5510
# Epoch 150/150
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.2603 - acc: 0.9179 - val_loss: 1.9717 - val_acc: 0.5325

# %%
# Mostramos la pérdida y el acierto por cada época

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Pérdida')
plt.xlabel('Época')
plt.show()

plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('% Acierto')
plt.xlabel('Época')
plt.show()

# %% [markdown]
# ## Ejercicio  1: Regularización por Dropout
#
# Para agregar  Dropout en keras simplemente usamos la capa `keras.layers.Dropout(p)` donde `p` es la probabilidad de dropout (de apagar una  neurona). Para agregar una de  estas capas simplemente usamos `add` como cualquier otra. Por ejemplo, podríamos hacer esto:
#
# ```
# red_reg = keras.Sequential()
# red_reg.add(keras.layers.Dense(30, input_dim=100, activation='relu'))
# red_reg.add(keras.layers.Dropout(0.2))
# red_reg.add(keras.layers.Dense(20, activation='relu'))
# ...
# ```
#
# Note que agregamos una capa de dropout entre la primera y la segunda capa.
#
# Crea una nueva red `red_reg` haciendo lo siguiente:
# - Agrega una capa de dropout entre cada una de  las capas escondidas de la red usando un dropout entre 0.2 y 0.5.
# - Entrena la red por 150 épocas para que veas cómo cambia el aprendizaje.
# - Guarda la historia del  entrenamiento en una variable `hist_reg` para luego poder graficarla junto a la historia del entrenamiento anterior.
# - Imprime el historial de la pérdida y el acierto para este nuevo entrenamiento.
# - Imprime el acierto del entrenamiento con y sin regularización en un mismo  gráfico.
#
# ¿Obtienes mejores resultados en cuanto al acierto?

# %% [markdown]
# ### a)  Crea y entrena la  red

# %%
# Setamos los seed para números random

np.random.seed(30)
tf.set_random_seed(30)

# Creamos nuestra red feed-forward

red_reg = keras.Sequential()

# Acá empieza tu código para crear red compilarla y entrenarla



# Acá termina tu código

# %% [markdown]
# ### b) Imprime el historial de entrenamiento

# %%
# Acá empieza tu código para mostrar el historial del nuevo entrenamiento


# Acá termina tu código

# %% [markdown]
# ### c) Compara el historial con y sin regularización

# %%
# Acá empieza tu código para la comparación del acierto
# con y sin regularización


# Acá termina tu código.

# %% [markdown]
# ### d) Muestra una grilla con ejemplos y las predicciones de la red

# %%
# Acá empieza tu código para mostrar una grilla con ejemplos
# y la predicción de la red.


    
# Acá termina tu código.

# %% [markdown]
# ## Ejercicio 2 (Opcional): Mejora el acierto en el test set
#
# Usa lo que  has aprendido de regularización para intentar mejorar el acierto en el test set. Puede intentar con un dropout más agresivo, cambiando el tamaño del batch (más pequeño puede mejorar pero demora la ejecución!), aumentando la capacidad de tu red, etc.
#
# Otro cambio  que puedes hacer es cambiar la tasa de aprendizaje.  Para eso puedes usar las funcionalidades en `keras.optimizers`.  Por ejemplo, para usar SGD con una tasa de aprendizaje de `0.001` puedes usar un código como este:
#
# ```
# # primero creas la red
# red = keras.Sequential()
# ...
#
# # antes de compilar creas el optimizador
# sgd_opt = keras.optimizers.SGD(lr=0.001)
#
# # al compilar usas el optimizador
# red.compile(
#     loss='categorical_crossentropy',
#     optimizer=sgd_opt,
#     metrics=['accuracy']
# )
#
# # ahora puedes entrenar como siempre
# red.fit(...)
# ...
#
# ```
#
# Incluso puedes hacer búsqueda de hiperparámetros para encontrar la mejor red respecto del acierto en el test set. Para esto puedes programar un loop en donde vas probando la red para distintos hiperparámetros. Si lo haces ordenado y estás dispuesto a esperar, puedes encontrar redes que mejoren sustancialmente las métricas.
